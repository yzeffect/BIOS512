# %% [markdown]
# Load the `TidyVerse` package.

# %%
library('tidyverse')
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Using the `head` 💀 function preview the `mpg` 🚗 dataset.

# %%
mpg |> head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %% [markdown]
# Each row in the `mpg` data represents one vehicle. Can you make the chart below ⬇ which shows the number of vehicles within each `class`?
#
# <div style="display:flex;justify-content:center;">
#     <img src="./bar_chart.png" style="width: 500px" />
# </div>

# %% [markdown]
# Hints:
#
# 1. Use `aes(y = class)` as the aesthetic encoding.
# 1. We won't use `geom_point` for this chart. Can you guess the name of the `geom_` function for a `bar` chart?

# %% [markdown]
# *Why can we get away with a single encoding here? How is each vehicle represented in the chart?*

# %%
# Not GGPLOT, simply a horizontal bar plot
    counts <- table(mpg$class)
    barplot(counts, main="Class vs Count", horiz=TRUE,
    names.arg=c("suv", "subcompact", "pickup", "minivan", "midsize", "compact", "2seater"))
# Out:
# Plot with title “Class vs Count”

# %%
# GGPLOT2 fill by class
p = ggplot(mpg, aes(y = class, fill = class)) +
    geom_bar()

p
# Out:
# plot without title

# %%
# GGPLOT2 color filled by carolina blue 	 #7BAFD4
p = ggplot(mpg, aes(y = class)) +
    geom_bar(fill="#7BAFD4")
           
p
# Out:
# plot without title
