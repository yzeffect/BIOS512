# %%
library('tidyverse')
options(repr.plot.width=4, repr.plot.height=3, repr.plot.res = 300)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.5     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # Tiles

# %% [markdown]
# This is a dataset of otter skull morphology.

# %%
# uncomment the following:
otter.data = read.csv('https://jcoliver.github.io/learn-r/data/otter-mandible-data.csv') %>%
    gather(characteristic, value, -species, -museum, -accession)

otter.data %>% head
# Out:
#   species    museum accession characteristic value
# 1 A. cinerea AMNH   101458    m1             15.100
# 2 A. cinerea AMNH   101461    m1             12.740
# 3 A. cinerea AMNH   101466    m1             12.425
# 4 A. cinerea AMNH   101635    m1             13.400
# 5 A. cinerea AMNH   101459    m1             14.400
# 6 A. cinerea AMNH   101462    m1             14.525

# %% [markdown]
# Make a bar chart of the museum column. What is this chart telling you?

# %%
options(repr.plot.width=4, repr.plot.height=3, repr.plot.res = 300)
p = ggplot(otter.data, aes(y = museum)) + 
    geom_bar(color = "#7BAFD4", fill = "#7BAFD4")
p
# Out:
# plot without title

# %% [markdown]
# Make a heatmap of the data with `characteristic` on the x-axis and `species` on the y-axis.

# %%
# uncomment this to get a scaled version of the data:

otter.data.scaled = otter.data %>%
    group_by(characteristic) %>%
    mutate(value.scaled = scales::rescale(value))

otter.data.scaled %>% head
# Out:
#   species    museum accession characteristic value  value.scaled
# 1 A. cinerea AMNH   101458    m1             15.100 0.27867699
# 2 A. cinerea AMNH   101461    m1             12.740 0.11259676
# 3 A. cinerea AMNH   101466    m1             12.425 0.09042928
# 4 A. cinerea AMNH   101635    m1             13.400 0.15904293
# 5 A. cinerea AMNH   101459    m1             14.400 0.22941590
# 6 A. cinerea AMNH   101462    m1             14.525 0.23821253

# %%
options(repr.plot.width=5, repr.plot.height=2.5, repr.plot.res = 300)

p = ggplot(otter.data.scaled, aes(x = characteristic, y = species, fill = value.scaled)) + 
    geom_tile(color = '#7BAFD4') + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

p
# Out:
# plot without title

# %% [markdown]
# What can you do to make the chart more visually appealing?
# - make the `color` white
# - use `scale_fill_gradient(low = "white", high = "steelblue")`

# %%
options(repr.plot.width=5, repr.plot.height=2.5, repr.plot.res = 300)

p = ggplot(otter.data.scaled, aes(x = characteristic, y = species, fill = value.scaled)) + 
    geom_tile(color = '#7BAFD4') + 
    scale_fill_gradient(low = "white", high = "#7BAFD4") +
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

p
# Out:
# plot without title

# %% [markdown]
# # Points with jitter

# %% [markdown]
# Let's stick with the otter data. We could also use a point+jitter plot to represent the data. Make a point+jitter plot below with species on the x-axis, value on the y-axis, and facet the chart by characteristic.

# %%
options(repr.plot.width=5, repr.plot.height=3, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value, color = characteristic)) + 
    geom_point()

p
# Out:
# Warning message:
# “Removed 5 rows containing missing values (geom_point).”
# plot without title

# %%
options(repr.plot.width=5, repr.plot.height=5, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    facet_wrap(~characteristic) +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    geom_point(na.rm = T, size = 0.5, alpha = 0.5, color = '#7BAFD4')

p
# Out:
# plot without title

# %%
options(repr.plot.width=5, repr.plot.height=5, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    facet_wrap(~characteristic, scales = 'free_y') +
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    geom_point(na.rm = T, size = 0.8, alpha = 0.5, color = '#7BAFD4', position = position_jitter(h = 0, w = 0.3))

p
# Out:
# plot without title

# %%
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    geom_boxplot(fill = NA, outlier.shape = NA) + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    geom_point(na.rm = T, size = 0.8, alpha = 0.5, color = '#7BAFD4', position = position_jitter(h = 0, w = 0.3))

p
# Out:
# Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=5, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    facet_wrap(~characteristic, scales = 'free_y') +
    geom_boxplot(fill = NA, outlier.shape = "star") + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    geom_point(na.rm = T, size = 0.8, alpha = 0.8, color = '#7BAFD4', position = position_jitter(h = 0, w = 0.3))

p
# Out:
# Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# Make the axis test legible by rotating the text 45 degrees.

# %%
options(repr.plot.width=5, repr.plot.height=5, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    geom_boxplot(na.rm = T, fill = NA, outlier.shape = NA) + 
    geom_point(na.rm = T, position = position_jitter(h = 0, w = 0.15), size = 0.5, color = '#7BAFD4') + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1))

p
# Out:
# plot without title

# %% [markdown]
# What happens if you pass the argument `scales='free_y` to `facet_wrap`?

# %%
options(repr.plot.width=6, repr.plot.height=6, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = characteristic, y = value)) + 
    geom_boxplot(na.rm = T, fill = NA, outlier.shape = NA) + 
    geom_point(na.rm = T, position = position_jitter(h = 0, w = 0.15), size = 0.5, color = '#7BAFD4') + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    facet_wrap(~species, scales = 'free_y')

p
# Out:
# plot without title

# %% [markdown]
# Do you prefer the heatmap or the point+jitter plot?

# %% [markdown]
# Point + jitter plot is much better because I don't understand what this heatmap is trying to say at all :)

# %%
options(repr.plot.width=4, repr.plot.height=6, repr.plot.res = 300)
p = ggplot(otter.data.scaled, aes(x = species, y = value)) + 
    geom_boxplot(fill = NA, outlier.shape = NA) + 
    geom_point(position = position_jitter(h = 0, w = 0.15), size = 0.5, color = '#7BAFD4') + 
    theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
    facet_wrap(~species, scales = 'free_y')

p
